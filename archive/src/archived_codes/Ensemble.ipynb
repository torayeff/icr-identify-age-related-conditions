# %%
from pathlib import Path

import catboost as cb
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler

# %%
data_path = Path("../data/")
seed = 42

# %%
def balanced_log_loss(y_true, y_pred):
    y_pred = np.clip(y_pred, 1e-15, 1 - 1e-15)

    n0, n1 = np.bincount(y_true.astype(int))
    w0 = 1 / (n0 / len(y_true))
    w1 = 1 / (n1 / len(y_true))

    l0 = -w0 / n0 * np.sum(np.where(y_true == 0, 1, 0) * np.log(1 - y_pred))
    l1 = -w1 / n1 * np.sum(np.where(y_true != 0, 1, 0) * np.log(y_pred))

    return (l0 + l1) / (w0 + w1)

# %%
# read data
train_df = pd.read_csv(data_path / "train.csv")
test_df = pd.read_csv(data_path / "test.csv")
greeks_df = pd.read_csv(data_path / "greeks.csv")

# %%
# some columns have trailing spaces
train_df.columns = train_df.columns.str.strip()
test_df.columns = test_df.columns.str.strip()
feature_cols = train_df.columns.tolist()[1:-1]

# %%
train_df, val_df = train_test_split(
    train_df, test_size=0.2, stratify=train_df["Class"], random_state=42
)
greeks_df = greeks_df.loc[train_df.index]

train_df = train_df.reset_index(drop=True)
greeks_df = greeks_df.reset_index(drop=True)

train_df.drop(columns=["Id"], inplace=True)

# %%
num_ensembles = 100

all_val_preds = []
all_test_preds = []
best_cv_score = np.inf
best_seed = 0

for ens in range(num_ensembles):
    print(f"Ensemble-{ens + 1}".center(150, "*"))
    # training

    under_sampler = RandomUnderSampler(random_state=ens)
    df, _ = under_sampler.fit_resample(train_df, train_df["Class"])

    oof_preds = np.zeros(len(df))
    val_preds = []
    test_preds = []

    fold = 1
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=ens)
    for train_idx, val_idx in skf.split(df, df["Class"]):
        # print(f"Fold-{fold}".center(110, "-"))
        fold += 1

        X_train, y_train = (
            df.loc[train_idx, feature_cols],
            df.loc[train_idx, "Class"],
        )

        X_val, y_val = (
            df.loc[val_idx, feature_cols],
            df.loc[val_idx, "Class"],
        )

        params = {
            "iterations": 10000,
            "early_stopping_rounds": 1000,
            "use_best_model": True,
            "random_seed": ens,
        }

        model = cb.CatBoostClassifier(**params)
        model.fit(
            X_train,
            y_train,
            eval_set=[(X_val, y_val)],
            cat_features=["EJ"],
            verbose=False,
        )

        # make oof preds
        oof_preds[val_idx] = model.predict_proba(X_val)[:, 1]

        # make val preds
        val_preds.append(model.predict_proba(val_df[feature_cols])[:, 1])

        # make test predictions
        # notice we are logging probs for both classes
        test_preds.append(model.predict_proba(test_df.iloc[:, 1:]))

    # print("-" * 110)
    print(f"OOF score: {balanced_log_loss(df['Class'], oof_preds):.4f}")
    cv_score = balanced_log_loss(val_df["Class"], np.mean(val_preds, axis=0))
    if cv_score < best_cv_score:
        best_cv_score = cv_score
        best_seed = ens
    print(f"CV score: {cv_score:.4f}")

    # save predictions
    all_val_preds.append(val_preds.copy())
    all_test_preds.append(test_preds.copy())

    print(f"Best cv score: {best_cv_score} at seed: {best_seed}")
# Out:
# **********************************************************************Ensemble-1**********************************************************************
# OOF score: 0.2565
# CV score: 0.3018
# Best cv score: 0.30183368929376114 at seed: 0
# **********************************************************************Ensemble-2**********************************************************************
# OOF score: 0.2843
# CV score: 0.3720
# Best cv score: 0.30183368929376114 at seed: 0
# **********************************************************************Ensemble-3**********************************************************************
# OOF score: 0.1918
# CV score: 0.2743
# Best cv score: 0.2742668153923849 at seed: 2
# **********************************************************************Ensemble-4**********************************************************************
# OOF score: 0.2412
# CV score: 0.2693
# Best cv score: 0.26930661684521306 at seed: 3
# **********************************************************************Ensemble-5**********************************************************************
# OOF score: 0.2895
# CV score: 0.3170
# Best cv score: 0.26930661684521306 at seed: 3
# **********************************************************************Ensemble-6**********************************************************************
# OOF score: 0.2239
# CV score: 0.3455
# Best cv score: 0.26930661684521306 at seed: 3
# **********************************************************************Ensemble-7**********************************************************************
# OOF score: 0.3190
# CV score: 0.3261
# Best cv score: 0.26930661684521306 at seed: 3
# **********************************************************************Ensemble-8**********************************************************************
# OOF score: 0.2391
# CV score: 0.3184
# Best cv score: 0.26930661684521306 at seed: 3
# **********************************************************************Ensemble-9**********************************************************************
# OOF score: 0.2943
# CV score: 0.3482
# Best cv score: 0.26930661684521306 at seed: 3
# *********************************************************************Ensemble-10**********************************************************************
# OOF score: 0.2699
# CV score: 0.3271
# Best cv score: 0.26930661684521306 at seed: 3
# *********************************************************************Ensemble-11**********************************************************************
# OOF score: 0.3282
# CV score: 0.3140
# Best cv score: 0.26930661684521306 at seed: 3
# *********************************************************************Ensemble-12**********************************************************************
# OOF score: 0.2753
# CV score: 0.3656
# Best cv score: 0.26930661684521306 at seed: 3
# *********************************************************************Ensemble-13**********************************************************************
# OOF score: 0.2846
# CV score: 0.3728
# Best cv score: 0.26930661684521306 at seed: 3
# *********************************************************************Ensemble-14**********************************************************************
# OOF score: 0.3472
# CV score: 0.2929
# Best cv score: 0.26930661684521306 at seed: 3
# *********************************************************************Ensemble-15**********************************************************************
# OOF score: 0.3010
# CV score: 0.3238
# Best cv score: 0.26930661684521306 at seed: 3
# *********************************************************************Ensemble-16**********************************************************************
# OOF score: 0.2581
# CV score: 0.3012
# Best cv score: 0.26930661684521306 at seed: 3
# *********************************************************************Ensemble-17**********************************************************************
# OOF score: 0.3135
# CV score: 0.3175
# Best cv score: 0.26930661684521306 at seed: 3
# *********************************************************************Ensemble-18**********************************************************************
# OOF score: 0.2305
# CV score: 0.3841
# Best cv score: 0.26930661684521306 at seed: 3
# *********************************************************************Ensemble-19**********************************************************************
# OOF score: 0.2698
# CV score: 0.3673
# Best cv score: 0.26930661684521306 at seed: 3
# *********************************************************************Ensemble-20**********************************************************************
# OOF score: 0.2565
# CV score: 0.2479
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-21**********************************************************************
# OOF score: 0.2809
# CV score: 0.3210
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-22**********************************************************************
# OOF score: 0.2887
# CV score: 0.3447
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-23**********************************************************************
# OOF score: 0.2507
# CV score: 0.3566
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-24**********************************************************************
# OOF score: 0.2289
# CV score: 0.3228
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-25**********************************************************************
# OOF score: 0.2734
# CV score: 0.3113
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-26**********************************************************************
# OOF score: 0.2788
# CV score: 0.3351
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-27**********************************************************************
# OOF score: 0.2068
# CV score: 0.3331
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-28**********************************************************************
# OOF score: 0.2395
# CV score: 0.3185
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-29**********************************************************************
# OOF score: 0.2506
# CV score: 0.3267
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-30**********************************************************************
# OOF score: 0.2483
# CV score: 0.3227
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-31**********************************************************************
# OOF score: 0.2497
# CV score: 0.2871
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-32**********************************************************************
# OOF score: 0.2688
# CV score: 0.2875
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-33**********************************************************************
# OOF score: 0.2756
# CV score: 0.3165
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-34**********************************************************************
# OOF score: 0.2298
# CV score: 0.3516
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-35**********************************************************************
# OOF score: 0.2680
# CV score: 0.2903
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-36**********************************************************************
# OOF score: 0.2616
# CV score: 0.3276
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-37**********************************************************************
# OOF score: 0.2548
# CV score: 0.2783
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-38**********************************************************************
# OOF score: 0.2829
# CV score: 0.2825
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-39**********************************************************************
# OOF score: 0.2652
# CV score: 0.3452
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-40**********************************************************************
# OOF score: 0.2853
# CV score: 0.3080
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-41**********************************************************************
# OOF score: 0.3417
# CV score: 0.3500
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-42**********************************************************************
# OOF score: 0.2322
# CV score: 0.2964
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-43**********************************************************************
# OOF score: 0.3125
# CV score: 0.2881
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-44**********************************************************************
# OOF score: 0.3200
# CV score: 0.3092
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-45**********************************************************************
# OOF score: 0.2524
# CV score: 0.3018
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-46**********************************************************************
# OOF score: 0.2620
# CV score: 0.3370
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-47**********************************************************************
# OOF score: 0.3113
# CV score: 0.3768
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-48**********************************************************************
# OOF score: 0.2495
# CV score: 0.3032
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-49**********************************************************************
# OOF score: 0.2992
# CV score: 0.3707
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-50**********************************************************************
# OOF score: 0.2528
# CV score: 0.3194
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-51**********************************************************************
# OOF score: 0.3010
# CV score: 0.3798
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-52**********************************************************************
# OOF score: 0.3173
# CV score: 0.3211
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-53**********************************************************************
# OOF score: 0.2948
# CV score: 0.3690
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-54**********************************************************************
# OOF score: 0.2577
# CV score: 0.3076
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-55**********************************************************************
# OOF score: 0.2621
# CV score: 0.3247
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-56**********************************************************************
# OOF score: 0.2940
# CV score: 0.3381
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-57**********************************************************************
# OOF score: 0.2509
# CV score: 0.3706
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-58**********************************************************************
# OOF score: 0.2629
# CV score: 0.3077
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-59**********************************************************************
# OOF score: 0.2262
# CV score: 0.3135
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-60**********************************************************************
# OOF score: 0.2586
# CV score: 0.2963
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-61**********************************************************************
# OOF score: 0.2710
# CV score: 0.3261
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-62**********************************************************************
# OOF score: 0.2774
# CV score: 0.3107
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-63**********************************************************************
# OOF score: 0.2540
# CV score: 0.3007
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-64**********************************************************************
# OOF score: 0.2071
# CV score: 0.3443
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-65**********************************************************************
# OOF score: 0.2442
# CV score: 0.2872
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-66**********************************************************************
# OOF score: 0.2828
# CV score: 0.3303
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-67**********************************************************************
# OOF score: 0.2660
# CV score: 0.3799
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-68**********************************************************************
# OOF score: 0.2609
# CV score: 0.3172
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-69**********************************************************************
# OOF score: 0.2965
# CV score: 0.3500
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-70**********************************************************************
# OOF score: 0.3138
# CV score: 0.3428
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-71**********************************************************************
# OOF score: 0.3611
# CV score: 0.3610
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-72**********************************************************************
# OOF score: 0.2148
# CV score: 0.3616
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-73**********************************************************************
# OOF score: 0.2654
# CV score: 0.3607
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-74**********************************************************************
# OOF score: 0.2599
# CV score: 0.3689
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-75**********************************************************************
# OOF score: 0.3276
# CV score: 0.3384
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-76**********************************************************************
# OOF score: 0.2395
# CV score: 0.3395
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-77**********************************************************************
# OOF score: 0.2856
# CV score: 0.3007
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-78**********************************************************************
# OOF score: 0.2305
# CV score: 0.3313
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-79**********************************************************************
# OOF score: 0.1976
# CV score: 0.3550
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-80**********************************************************************
# OOF score: 0.2657
# CV score: 0.3022
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-81**********************************************************************
# OOF score: 0.2344
# CV score: 0.3263
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-82**********************************************************************
# OOF score: 0.2350
# CV score: 0.3030
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-83**********************************************************************
# OOF score: 0.2876
# CV score: 0.3129
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-84**********************************************************************
# OOF score: 0.2928
# CV score: 0.3111
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-85**********************************************************************
# OOF score: 0.2795
# CV score: 0.3588
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-86**********************************************************************
# OOF score: 0.3138
# CV score: 0.3632
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-87**********************************************************************
# OOF score: 0.2416
# CV score: 0.3406
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-88**********************************************************************
# OOF score: 0.2542
# CV score: 0.2903
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-89**********************************************************************
# OOF score: 0.2176
# CV score: 0.3193
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-90**********************************************************************
# OOF score: 0.2634
# CV score: 0.3670
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-91**********************************************************************
# OOF score: 0.2994
# CV score: 0.3034
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-92**********************************************************************
# OOF score: 0.2734
# CV score: 0.3173
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-93**********************************************************************
# OOF score: 0.2684
# CV score: 0.3412
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-94**********************************************************************
# OOF score: 0.3185
# CV score: 0.3503
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-95**********************************************************************
# OOF score: 0.2357
# CV score: 0.2696
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-96**********************************************************************
# OOF score: 0.2375
# CV score: 0.2921
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-97**********************************************************************
# OOF score: 0.2447
# CV score: 0.3247
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-98**********************************************************************
# OOF score: 0.2883
# CV score: 0.3041
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-99**********************************************************************
# OOF score: 0.2847
# CV score: 0.3231
# Best cv score: 0.24787572973075 at seed: 19
# *********************************************************************Ensemble-100*********************************************************************
# OOF score: 0.2323
# CV score: 0.4185
# Best cv score: 0.24787572973075 at seed: 19

# %%
mean_val_preds = np.mean(np.mean(all_val_preds, axis=1), axis=0)
print(f"CV score: {balanced_log_loss(val_df['Class'], mean_val_preds):.4f}")
# Out:
# CV score: 0.3088

# %%
# generate a submission file
test_probs = np.mean(np.mean(all_test_preds, axis=1), axis=0)
sub_df = pd.DataFrame(
    {"Id": test_df.Id, "Class_0": test_probs[:, 0], "Class_1": test_probs[:, 1]}
)
sub_df.to_csv("submission.csv", index=False)
